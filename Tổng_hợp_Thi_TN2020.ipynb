# %% [markdown]
# <a href="https://colab.research.google.com/github/Theanh130124/Datamining_srccode/blob/main/T%C3%B4%CC%89ng_h%C6%A1%CC%A3p_Thi_TN2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Load dữ liệu lên

# %%
import pandas as pd
file = ('/content/Full_Mark_2020.csv')
df = pd.read_csv(file)
df.columns= ['No','Code','Diali','GDCD','Hoahoc','KHTN','KHXH','LichSu','Ngoaingu','NguVan','Sinhhoc','Toan','Vatli','city']
df.info()

#No ra 1051860
#COde cũng vậy
# Out:
# <ipython-input-39-6d9338ee60a1>:3: DtypeWarning: Columns (1,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1051860 entries, 0 to 1051859
# Data columns (total 14 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   No        1051860 non-null  int64
#  1   Code      1051860 non-null  object
#  2   Diali     677017 non-null   float64
#  3   GDCD      583615 non-null   float64
#  4   Hoahoc    351098 non-null   float64
#  5   KHTN      340016 non-null   float64
#  6   KHXH      583173 non-null   float64
#  7   LichSu    692753 non-null   float64
#  8   Ngoaingu  927333 non-null   float64
#  9   NguVan    1034987 non-null  float64
#  10  Sinhhoc   344830 non-null   float64
#  11  Toan      1047277 non-null  float64
#  12  Vatli     348615 non-null   object
#  13  city      1051860 non-null  object
# ...

# %% [markdown]
# Hai dòng đầu tiên chuyển đổi cột 'Vatli' và 'city' sang kiểu dữ liệu số. Nếu có lỗi, nó sẽ thay thế giá trị lỗi bằng NaN. df.info() sau đó được gọi để hiển thị thông tin tóm tắt về DataFrame df sau khi đã chuyển đổi kiểu dữ liệu của cột 'Vatli' và 'city'.

# %%
df['Code'] = pd.to_numeric(df['Code'], errors='coerce')
df['Vatli'] =pd.to_numeric(df['Vatli'], errors='coerce')
df['city'] = pd.to_numeric(df['city'], errors='coerce')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1051860 entries, 0 to 1051859
# Data columns (total 14 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   No        1051860 non-null  int64
#  1   Code      1051854 non-null  float64
#  2   Diali     677017 non-null   float64
#  3   GDCD      583615 non-null   float64
#  4   Hoahoc    351098 non-null   float64
#  5   KHTN      340016 non-null   float64
#  6   KHXH      583173 non-null   float64
#  7   LichSu    692753 non-null   float64
#  8   Ngoaingu  927333 non-null   float64
#  9   NguVan    1034987 non-null  float64
#  10  Sinhhoc   344830 non-null   float64
#  11  Toan      1047277 non-null  float64
#  12  Vatli     348613 non-null   float64
#  13  city      1051854 non-null  float64
# dtypes: float64(13), int64(1)
# memory usage: 112.4 MB

# %%
#Kiểm tra dữ liệu trùng lặp
duplicate_rows = df[df.duplicated(subset='Code')]
print('Số lượng dữ liệu trùng lâp: ' ,len(duplicate_rows))
# Out:
# Số lượng dữ liệu trùng lâp:  190904

# %%
df = df.drop_duplicates(subset='Code')
df
#860965 row x 14 col
# Out:
#               No        Code  Diali  GDCD  Hoahoc  KHTN  KHXH  LichSu  \
# 0              0  44000001.0    NaN   NaN    8.00  7.08   NaN     NaN
# 1              1  44000002.0    NaN   NaN    8.25  7.17   NaN     NaN
# 2              2  44000003.0    NaN   NaN    4.50  4.92   NaN     NaN
# 3              3  44000004.0   7.50  9.25     NaN   NaN  8.67    9.25
# 4              4  44000005.0   8.00  9.00     NaN   NaN  8.50    8.50
# ...          ...         ...    ...   ...     ...   ...   ...     ...
# 1051855  1051855  13007414.0   5.25  4.25     NaN   NaN  4.08    2.75
# 1051856  1051856  13007415.0   5.25  6.25     NaN   NaN  5.83    6.00
# 1051857  1051857  13007416.0   5.75  8.50     NaN   NaN  6.67    5.75
# 1051858  1051858  13007417.0   7.25  6.75     NaN   NaN  6.25    4.75
# 1051859  1051859  13007418.0   3.75  4.00     NaN   NaN  3.83    3.75
#
#          Ngoaingu  NguVan  Sinhhoc  Toan  Vatli  city
# 0             4.4    7.50     5.50   8.4   7.75  44.0
# ...

# %%
#Từ kết quả trên ta thấy có 971038 rows -> thí sinh
my_df = df
my_df['Code'] = range(1 , len(my_df) + 1)
my_df
# Out:
#               No    Code  Diali  GDCD  Hoahoc  KHTN  KHXH  LichSu  Ngoaingu  \
# 0              0       1    NaN   NaN    8.00  7.08   NaN     NaN       4.4
# 1              1       2    NaN   NaN    8.25  7.17   NaN     NaN       NaN
# 2              2       3    NaN   NaN    4.50  4.92   NaN     NaN       4.0
# 3              3       4   7.50  9.25     NaN   NaN  8.67    9.25       7.4
# 4              4       5   8.00  9.00     NaN   NaN  8.50    8.50       9.2
# ...          ...     ...    ...   ...     ...   ...   ...     ...       ...
# 1051855  1051855  860952   5.25  4.25     NaN   NaN  4.08    2.75       2.8
# 1051856  1051856  860953   5.25  6.25     NaN   NaN  5.83    6.00       3.8
# 1051857  1051857  860954   5.75  8.50     NaN   NaN  6.67    5.75       3.4
# 1051858  1051858  860955   7.25  6.75     NaN   NaN  6.25    4.75       2.2
# 1051859  1051859  860956   3.75  4.00     NaN   NaN  3.83    3.75       4.0
#
#          NguVan  Sinhhoc  Toan  Vatli  city
# ...

# %%
#Đếm số lượng thí sinh không thi cả hai mon KHTN và KHXH
count_no_exam = len(my_df[(my_df['KHTN'].isnull()) & (my_df['KHXH'].isnull())])
#Đếm số lượng thí sinh tham gia cả hai môn KHTN và KHXH
count_both_exam = len(my_df[(my_df['KHTN'].notnull()) & (my_df['KHXH'].notnull())])
#Hiển thị kết quả
print(f"Số lượng thí sinh không thi cả hai môn KHTN và KHXH: {count_no_exam}")
print(f'Số lượng thí sinh thi cả hai môn KHTN và KHXH: {count_both_exam}')
# Out:
# Số lượng thí sinh không thi cả hai môn KHTN và KHXH: 101023
# Số lượng thí sinh thi cả hai môn KHTN và KHXH: 1

# %%
#Tách dataframe my_df thành my_df_khtn và my_df_khxh
my_df_khtn = my_df[my_df['KHTN'].notnull()]
my_df_khxh = my_df[my_df['KHXH'].notnull()]
my_df_khtn.info()
my_df_khxh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 283794 entries, 0 to 1051740
# Data columns (total 14 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   No        283794 non-null  int64
#  1   Code      283794 non-null  int64
#  2   Diali     1 non-null       float64
#  3   GDCD      1 non-null       float64
#  4   Hoahoc    283794 non-null  float64
#  5   KHTN      283794 non-null  float64
#  6   KHXH      1 non-null       float64
#  7   LichSu    1 non-null       float64
#  8   Ngoaingu  278995 non-null  float64
#  9   NguVan    281753 non-null  float64
#  10  Sinhhoc   283794 non-null  float64
#  11  Toan      283779 non-null  float64
#  12  Vatli     283794 non-null  float64
#  13  city      283794 non-null  float64
# dtypes: float64(12), int64(2)
# memory usage: 32.5 MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 476140 entries, 3 to 1051859
# Data columns (total 14 columns):
#  #   Column    Non-Null Count   Dtype
# ...

# %% [markdown]
# LỌC ĐIỂM THI TỔNG HỢP KHỐI KHTN VÀ KHXH tài TP.HCM

# %%
df_khtn_hcm = my_df_khtn[(my_df_khtn['city'] == 2)]
df_khtn_hcm.to_csv('khtn_hcm.cvs')
df_khxh_hcm = my_df_khxh[(my_df_khxh['city'] == 2)]
df_khxh_hcm.to_csv('khxh_hcm.cvs')

# %%
#Lọc ra các cột cần tính toán của tất cả
my_df_khtn = my_df_khtn[['Toan','NguVan','Ngoaingu','Vatli','Hoahoc','Sinhhoc']]
my_df_khtn.info()
my_df_khxh = my_df_khxh[['Toan','NguVan','Ngoaingu','LichSu','Diali','GDCD']]
my_df_khxh.info()

#283779
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 283794 entries, 0 to 1051740
# Data columns (total 6 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Toan      283779 non-null  float64
#  1   NguVan    281753 non-null  float64
#  2   Ngoaingu  278995 non-null  float64
#  3   Vatli     283794 non-null  float64
#  4   Hoahoc    283794 non-null  float64
#  5   Sinhhoc   283794 non-null  float64
# dtypes: float64(6)
# memory usage: 15.2 MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 476140 entries, 3 to 1051859
# Data columns (total 6 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Toan      475705 non-null  float64
#  1   NguVan    475959 non-null  float64
#  2   Ngoaingu  474173 non-null  float64
#  3   LichSu    476140 non-null  float64
#  4   Diali     476140 non-null  float64
#  5   GDCD      476140 non-null  float64
# dtypes: float64(6)
# memory usage: 25.4 MB

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
#Tiền xử lý dữ liệu
my_df_khtn.fillna(my_df_khtn.mean(), inplace=True)
# my_df_khxh.fillna(my_df_khxh.mean(), inplace=True)

# %%
#Tìm số cụm tối ưu sử dụng phương pháp Elbow
max_clusters = 10
sse = []
for k in range(2, max_clusters + 1):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(my_df_khtn)
    sse.append(kmeans.inertia_)
#Vẽ biểu đồ Elbow
plt.plot(range(2, max_clusters + 1), sse, marker='o')
plt.xlabel('Số lượng cụm')
plt.ylabel('SSE')
plt.title('Phương pháp Elbow')
plt.show()

# %%
#Số cụm tối uuw dưa trên biểu đồ Elbow
num_clusters = 5
#Ap dụng thuật toán K-means
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(my_df_khtn)
#Gán nhãn cụm cho dữ liệu
my_df_khtn['Cluster'] = kmeans.labels_
#Vẽ biểu đồ phân cụm
plt.scatter(my_df_khtn['Cluster'],my_df_khtn['Toan'], c=my_df_khtn['Cluster'], cmap='viridis')
plt.xlabel('Cluster')
plt.ylabel('Toan')
plt.title('Phân cụm K-means')
plt.show()
#

# %%
my_df_khtn[['Toan','NguVan']].round(2)
#
# Out:
#          Toan  NguVan
# 0         8.4    7.50
# 1         7.6    6.00
# 2         7.0    5.00
# 5         8.4    6.75
# 8         8.6    7.50
# ...       ...     ...
# 1051526   6.4    6.00
# 1051662   8.2    7.25
# 1051668   7.8    6.25
# 1051729   6.4    4.25
# 1051740   6.0    5.75
#
# [283794 rows x 2 columns]

# %%
import numpy as np
def kmeans_display(X, label):
    K = np.amax(label) + 1
    X0 = X[label == 0, :]
    X1 = X[label == 1, :]
    X2 = X[label == 2, :]

    plt.plot(X0[:, 0], X0[:, 1], 'b^', markersize = 4, alpha = .8)
    plt.plot(X1[:, 0], X1[:, 1], 'go', markersize = 4, alpha = .8)
    plt.plot(X2[:, 0], X2[:, 1], 'rs', markersize = 4, alpha = .8)

    plt.axis('equal')
    plt.plot()
    plt.show()
  #Số cụm tối ưu dựa trên biểu đồ Elbow
num_clusters = 5
#Ap dụng thuật toán K-means
kmeans = KMeans(n_clusters=num_clusters, random_state=0).fit(my_df_khtn[['Toan','NguVan']])
#
print('Center found by sckiit-leanr:\n', kmeans.cluster_centers_)

pred_label = kmeans.predict(my_df_khtn[['Toan','NguVan']])
kmeans_display(my_df_khtn[['Toan','NguVan']].values, pred_label)
#
  #Gán nhãn cụm cho dữ liệu
# Out:
# Center found by sckiit-leanr:
#  [[8.75303002 6.6344873 ]
#  [7.36541256 6.97807467]
#  [8.55025698 7.91244466]
#  [5.73601849 6.01429575]
#  [8.08318944 5.28651227]]

# %%
my_df_khtn.to_csv('diemthi.csv')

# %% [markdown]
# **CÂU 2: Số bài thi môn toán phổ điểm bài thi của môn toán ** - BÀI THỰC HÀNH 2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Đọc dữ liệu từ file CSV (thay đổi đường dẫn file nếu cần)
# Sử dụng pd.read_csv để đọc file CSV
df_hcm = pd.read_csv('/content/Full_Mark_2020.csv')


# Kết hợp hai DataFrame
df_all = pd.concat([df_hcm, df_hn])

# Tạo bins cho mức điểm (0.2, 0.4, 0.6, ..., 9.8, 10)
bins = [i/5 for i in range(0, 51)]

# Vẽ histogram
plt.hist(df_all['Toan'], bins=bins, edgecolor='black')

# Đặt tiêu đề và nhãn trục
plt.title('Phân bố điểm thi môn Toán (Tất cả thí sinh)')
plt.xlabel('Điểm')
plt.ylabel('Số bài thi')
# Thiết lập các ticks trên trục x
plt.xticks(bins , rotation=45 , fontsize=8)

plt.tight_layout()




# Hiển thị biểu đồ
plt.show()
# Out:
# <ipython-input-62-99f7759d06d2>:6: DtypeWarning: Columns (1,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_hcm = pd.read_csv('/content/Full_Mark_2020.csv')

# %% [markdown]
# Tính điểm trung bình điểm trung vị độ lệch chuẩn

# %%
import pandas as pd

# Tính toán các giá trị thống kê
diem_trung_binh = df['Toan'].mean()
diem_trung_vi = df['Toan'].median()
do_lech_chuan = df['Toan'].std()

# Tạo DataFrame tổng hợp
data = {'Giá trị': ['Điểm trung bình', 'Điểm trung vị', 'Độ lệch chuẩn'],
        'Toán': [diem_trung_binh, diem_trung_vi, do_lech_chuan]}
bang_tong_hop = pd.DataFrame(data)

# Hiển thị bảng
bang_tong_hop
# Out:
#            Giá trị      Toán
# 0  Điểm trung bình  6.668620
# 1    Điểm trung vị  7.000000
# 2    Độ lệch chuẩn  1.816566

# %% [markdown]
# Tổng hợp thí sinh HCM ,thí sinh Hà Nội

# %%
print(df['city'].unique())
# Out:
# [44. 60. 51. 52. 18. 11. 19. 56. 37. 43. 47. 61. 55.  6.  3. 40. 63. 62.
#  nan 48. 50. 38.  5. 24.  1. 30. 21.  2. 64. 23. 22. 41. 54. 36.  7. 42.
#  10.  8. 49. 25. 29. 27. 45. 15. 39. 31. 35. 17. 32. 59. 14. 46. 26. 12.
#  28. 33. 53. 58.  9. 57. 16. 13.]

# %%
import pandas as pd

# Lọc dữ liệu cho thí sinh thuộc thành phố HCM
df_hcm = df[df['city'] == 2]  # Giả sử 1 là giá trị đại diện cho thành phố HCM trong cột 'city'

# Lọc dữ liệu cho thí sinh thuộc thành phố Hà Nội
df_hn = df[df['city'] == 1]   # Giả sử 2 là giá trị đại diện cho thành phố Hà Nội trong cột 'city'

# Lưu DataFrame vào file Excel
df_hcm.to_excel('thi_sinh_hcm_1.xlsx', index=False)
df_hn.to_excel('thi_sinh_hn_1.xlsx', index=False)
df_hcm
df_hn
# Out:
#             No    Code  Diali  GDCD  Hoahoc  KHTN  KHXH  LichSu  Ngoaingu  \
# 272862  272862  267255    NaN   NaN     NaN   NaN   NaN    8.00       NaN
# 272863  272863  267256    NaN   NaN    8.75  7.75   NaN     NaN       9.4
# 272864  272864  267257    NaN   NaN    8.75  7.25   NaN     NaN       6.0
# 272865  272865  267258    NaN   NaN    6.00   NaN   NaN     NaN       8.2
# 272866  272866  267259   7.25  9.25     NaN   NaN  7.42    5.75       9.2
# ...        ...     ...    ...   ...     ...   ...   ...     ...       ...
# 351719  351719  346112   7.00  8.25     NaN   NaN  7.08    6.00       9.0
# 351720  351720  346113    NaN   NaN    3.75  3.17   NaN     NaN       6.0
# 351721  351721  346114   5.75  7.75     NaN   NaN  6.17    5.00       3.2
# 351722  351722  346115    NaN   NaN    3.50  5.42   NaN     NaN       7.0
# 351723  351723  346116   6.50  6.50     NaN   NaN  5.75    4.25       3.2
#
#         NguVan  Sinhhoc  Toan  Vatli  city
# ...

# %%
# Out:
#            No   Code  Diali  GDCD  Hoahoc   KHTN   KHXH  LichSu  Ngoaingu  \
# 0      539538      1   7.00  7.25     NaN    NaN  26.25    5.75       5.2
# 1      539539      2   7.25  8.50     NaN    NaN  30.50    7.00       7.0
# 2      539540      3   7.75  8.25     NaN    NaN  27.50    4.75       6.0
# 3      539541      4    NaN   NaN    6.25  26.55    NaN     NaN       5.6
# 4      539542      5    NaN   NaN    6.25  24.90    NaN     NaN       8.2
# ...       ...    ...    ...   ...     ...    ...    ...     ...       ...
# 74448  613986  74449    NaN   NaN    5.00  19.40    NaN     NaN       NaN
# 74449  613987  74450    NaN   NaN    8.75  32.35    NaN     NaN       6.2
# 74450  613988  74451    NaN   NaN    8.50  34.70    NaN     NaN       6.2
# 74451  613989  74452    NaN   NaN    9.25  33.00    NaN     NaN       7.0
# 74452  613990  74453   7.25   NaN     NaN    NaN    NaN    6.50       NaN
#
#        NguVan  Sinhhoc  Toan  Vatli  city
# ...
